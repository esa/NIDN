# %%
### Imports (TODO remove this when finished)
# %load_ext autoreload
# %autoreload 2

# Append root folder in case you haven't installed NIDN
import sys
sys.path.append("../..")

import nidn
from glob import glob
# Out:
# 14:10:49|NIDN-INFO| Initialized NIDN for cpu
# 14:10:49|NIDN-INFO| Using double precision

# %%
runs = glob("../results/*.pk")
# Iterate over runs
for file in runs:
    cfg = nidn.load_run(file)
    nidn.plot_spectra(cfg)
    nidn.plot_eps_per_point(cfg)
# Out:
# 14:13:14|NIDN-INFO| Loaded run config from ../results/single_layer_reg19-05-2022 14-09-49_run.pk
# 14:13:14|NIDN-INFO| Loaded run config from ../results/1layer_rcwa_reg_19-05-2022 14-10-06_run.pk
# 14:13:15|NIDN-INFO| Loaded run config from ../results/19-05-2022 14-08-34_run.pk
